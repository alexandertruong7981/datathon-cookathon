# %%
# Import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#                 id observation_timestamp       station  year  month  day  \
# 0  AQ_249AF8D9D878   2013-03-01 00:00:00  Aotizhongxin  2013      3    1
# 1  AQ_EB620EFFEEC8   2013-03-01 00:00:00     Changping  2013      3    1
# 2  AQ_27EEFC23DFA3   2013-03-01 00:00:00      Dingling  2013      3    1
# 3  AQ_C2DEB5BEFD7E   2013-03-01 00:00:00        Dongsi  2013      3    1
# 4  AQ_8B32BEDFDF0D   2013-03-01 00:00:00      Guanyuan  2013      3    1
#
#    hour  PM10   SO2   NO2     CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM  \
# 0     0   4.0   4.0   7.0  300.0  77.0  -0.7  1023.0 -18.8   0.0  NNW   4.4
# 1     0   6.0  13.0   7.0  300.0  85.0  -2.3  1020.8 -19.7   0.0    E   0.5
# 2     0   4.0   3.0   NaN  200.0  82.0  -2.3  1020.8 -19.7   0.0    E   0.5
# 3     0   9.0   3.0  17.0  300.0  89.0  -0.5  1024.5 -21.4   0.0  NNW   5.7
# 4     0   4.0  14.0  20.0  300.0  69.0  -0.7  1023.0 -18.8   0.0  NNW   4.4
#
#    PM2_5_next_hour
# 0              8.0
# 1              3.0
# 2              7.0
# 3              4.0
# 4              4.0

# %%
# define target var
target = df["PM2_5_next_hour"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360954 entries, 0 to 360953
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     360954 non-null  object
#  1   observation_timestamp  360954 non-null  object
#  2   station                360954 non-null  object
#  3   year                   360954 non-null  int64
#  4   month                  360954 non-null  int64
#  5   day                    360954 non-null  int64
#  6   hour                   360954 non-null  int64
#  7   PM10                   359032 non-null  float64
#  8   SO2                    356291 non-null  float64
#  9   NO2                    353433 non-null  float64
#  10  CO                     345122 non-null  float64
#  11  O3                     352455 non-null  float64
#  12  TEMP                   360777 non-null  float64
#  13  PRES                   360776 non-null  float64
#  14  DEWP                   360772 non-null  float64
#  15  RAIN                   360780 non-null  float64
#  16  wd                     360161 non-null  object
#  17  WSPM                   360779 non-null  float64
#  18  PM2_5_next_hour        360954 non-null  float64
# dtypes: float64(11), int64(4), object(4)
# memory usage: 52.3+ MB

# %%
df.isnull().sum()
# Out:
# id                           0
# observation_timestamp        0
# station                      0
# year                         0
# month                        0
# day                          0
# hour                         0
# PM10                      1922
# SO2                       4663
# NO2                       7521
# CO                       15832
# O3                        8499
# TEMP                       177
# PRES                       178
# DEWP                       182
# RAIN                       174
# wd                         793
# WSPM                       175
# PM2_5_next_hour              0
# dtype: int64

# %%
# Investigate dist of target variable

sns.histplot(target, bins=40, kde=True)
plt.show()

# %% [markdown]
# Log transformations can help distribution/variance

# %%
sns.boxplot(y = target)
plt.show()

# %%
df.describe().round(4)
# Out:
#               year        month          day         hour         PM10  \
# count  360954.0000  360954.0000  360954.0000  360954.0000  359032.0000
# mean     2014.4258       6.3699      15.7493      11.4932     103.5245
# std         1.0522       3.2778       8.8036       6.9347      88.9152
# min      2013.0000       1.0000       1.0000       0.0000       2.0000
# 25%      2014.0000       4.0000       8.0000       5.0000      37.0000
# 50%      2014.0000       6.0000      16.0000      11.0000      82.0000
# 75%      2015.0000       9.0000      23.0000      18.0000     144.0000
# max      2016.0000      12.0000      31.0000      23.0000     999.0000
#
#                SO2          NO2           CO           O3         TEMP  \
# count  356291.0000  353433.0000  345122.0000  352455.0000  360777.0000
# mean       16.3760      49.4879    1184.5083      60.8432      14.4727
# std        22.3955      34.3746    1085.4396      58.1102      11.3764
# min         0.2856       1.0265     100.0000       0.2142     -19.9000
# 25%         3.0000      23.0000     500.0000      13.0000       4.4000
# 50%         7.7112      42.0000     900.0000      49.0000      16.1000
# 75%        20.0000      69.0000    1500.0000      86.0000      23.9000
# max       500.0000     290.0000   10000.0000    1071.0000      41.6000
#
#               PRES         DEWP         RAIN         WSPM  PM2_5_next_hour
# count  360776.0000  360772.0000  360780.0000  360779.0000      360954.0000
# mean     1009.7566       3.2827       0.0668       1.7346          78.0440
# std        10.3466      13.8303       0.8321       1.2505          77.7779
# min       982.4000     -43.4000       0.0000       0.0000           2.0000
# 25%      1001.4000      -8.1000       0.0000       0.9000          21.0000
# 50%      1009.0000       4.5000       0.0000       1.4000          55.0000
# 75%      1017.8000      15.8000       0.0000       2.2000         108.0000
# max      1042.8000      29.1000      72.5000      13.2000         999.0000
